# %% [markdown]
# # Week 2 Notes
#
# ## Monday 11/20/17 6pm-10pm
#
# ### Class Intro- Going over class deliverables (25 min)
#
# - Mary: Did not have a chance to work on hers, set new due date for this Saturday 11/25/17
# - Kaleo: Didn't complete his deliverable, is going to do Medium blog and also set a a due date for Saturday 11/25/17
# - Nick: Not sure on what to do
# - Ross: Reverse engineering, How does Cheat Engine work? Live Demo was awesome!(25 min)
#     - Hack FTL Game using Cheat Engine
#     - Change value of money in game
#     - View assembly code in Cheat Engine
#     - Cracked program "crackme" using Cheat Engine
# - Bart: Got key concepts on Registers and assembly, posted a one pager medium post
# [Bart Medium Post](https://medium.com/@globalfuture/programming-language-one-page-d1b948c56f15)
#
# ### Work on Deliverables (60 minutes approx)
#
# ### Lecture (90 min)
#
# - Setting up Playbook
#     - Should be in a specific Location
#     - Cd in directory and startup Jupyter Notebook
#     - Browser based file explorer, so you need to start it where you want to work on it
#
# - Set a BIOS password for our built computers
#     - 1st level of securing hardware is our BIOS password
#     - Wont boot without password
#     - Lab to practice using bootable thumb drive to startup machine
#     - Remove motherboard for about 15min will remove BIOS password
#     - MAC's have UEFI settings (command+R)
#     - Lock down boot order in BIOS (So someone couldn't boot through USB)
#     [Resource](http://resources.infosecinstitute.com/anatomy-of-bios-security/#gref)
#
# - Grub is a Linux bootloader
# - Windows command to view boot manager (bcdedit /enum)
#
#
# - Jupyter
#     - At console type git status- red files show modified files
#     - to add file git add. or git add filename
#     - git status- shows green if files have been tagged but not committed
#     - git commit -m "Commit Message"
#     - git push -> Then go to github to see files/changes
#
# - Registry
#     - Giant database in windows that stores settings
#     - folder options -> view -> hidden files and folders -> show hidden files and folders
#     - windows c drive -> windows -> system32 -> config
#     - regedit- tool built into windows for accessing the registry
#     - Highly targeted area becuase of stored default settings
#     - usrclass.dat
#
#
# ## Tuesday 11/21/17
#
# ### Class Intro (About 2 hours)
#
# - Download different virtual machines for virtualbox (Windows 7, Windows 10, and maybe Linux)
# - [Free Windows Downloads](https://developer.microsoft.com/en-us/microsoft-edge/tools/vms/)
#
# - Open up Windows 7 and windows 10
# - type regedit at start to open registry
# - Backup registry file before playing with
# - 4 default data types
#     - reg is the prefix
#     - string
#     - binary
#     - dword(32bit)
#     - qword(64bit)
# - Can change registry settings and files to make tweaks
#
# - Scripting
#
# - Add a key to the registry in CLI *reg add "HKCU\SOFTWARE\Microsoft\Windows\Currentversion\Run" /v "Mymalicousprogroam" /t REG_S2 /f /d C:
#
# - Create a script
#     - Create a new text file -> "MyScript.bat"
#     - Go to folder settings and change to allow changes in file
#     - In text file type
#         - reg query HKLM\Software >> test.txt
#         - ipconfig /all >> test.txt
#         - PAUSE
