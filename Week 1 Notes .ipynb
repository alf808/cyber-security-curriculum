# %% [markdown]
# # Week 1
#
# ## Monday Day 1- 11/13/17: 6-10pm
#
# ### 1. Introductions (about 20 minutes- 4 students + Jason, Tyler, Alyssa)
#
# Ross
#     - Computer Science Degree
#     - Wants a Cyber Security Job
#     - Has had IT Jobs (Networking) No firewalls
#         - Install servers
#         - UPS's, Switches
#         - Basic troubleshooting
#         - Basic Help desk work
#     - Interested in Pen Testing
#     - How can hardware or software be compromised
#
# Nick
#     - No background in Cyber Security
#         - Built his own computers
#         - Video Gamer
#     - Knows a little python
#     - Thinks there is a high demand of cyber security and wants to get a Job in Cyber Security
#
# Kaleo
#     - No background in Cyber Security
#     - Bachelors in electrical engineering
#     - Some programming
#     - Thinks Cyber Security is a cool field and wants to learn more
#     - Project engineer for a construction Company now
#         - Managment
#         - Design drawings and specks
# Bart
#     - Political Science degree and Sustainable development degree
#     - Defense Contrator and Emergency manager now
#     - Does a lot of Policy and Planning
#     - Interested in Penetration testing
#     - Weak in technical knowledge
#     - Very enthusiastic
#
# ### 2. Course Guidelines and Expectations (40 minutes)
#
# #### 3.  7:10- 7:30 (20 Minute Break)
#
# ### 4. Accounts Created and Programs Downloaded (1:15 min)
# - Anaconda
# - Git
# - Keybase
# - Virtualbox
# - Python
#
# |Programs    |       Ross    |    Kaleo       |   Tyler       |   Bart       |   Nick        |   Jason     |   Alyssa     |
# |------------|---------------|----------------|---------------|--------------|---------------|-------------|------------  |
# |github      | carrotshaver  |   kaleonorman  | Tylernchls    | ruggedinfo   | pandacarry    | jaywon      | alyssaknight |
# |twitter     | carrot_shaver |   kknorman     | N/A           | N/A          | nicklaus_park | sewell_jason| N/A          |
# |medium      | RossM         |   kaleonorman  | Tylernchls    | Bart Abbot   | nicklaus_park | jaywon      | alyssaknight |
# |keybase     | carrotshaver  |   kaleonorman  | Tylernchls464 | rugged_info  | parkn         | jaywon      | alyssak      |
# |machine specs | win10/8gR/i5| win10/8gR/i5   |               | win10/8gR/i7 | win10/8gr/i5  |             |              |
#
# ### 5. Jupyter Demo (1 hour approx)
#
# - Created Playbook
# - What is markdown
# - You can live code
# - Its a server so you can access without internet
# - Generated ssh private key (RSA command)
# - Authenticated ssh key on github
# - Pushing Jupyter to Github
# - Git bash commands

# %% [markdown]
# ## Tuesday Day 2- 11/14/17: 6-10pm
#
# ### 1. Introduction (took 40 min)
# - Trello demo and setup (20 minutes)
#     - Trello (How we manage week to week)- Task Management and how you individually keep track of vocab
#     - Create a Trello account, create a board name it "YourName Cyber Backlog" -> Invite Instructors
# - Jupyter/Github
#     - Technical Documentation/notes
#     - Explain category from
# - Medium
#     - Technical Writing
# - Getting Certified (A+, Network +, Security +)
#
# ### 2. Lecture (1 hour)
# Topics
# - x=5 x+10 -> Assembly -> Binary
# - Understanding binary allows you to make applications and understand vulnerabilities
# - CPU's process binary instructions
# - system clock
# - 4 components of a CPU
#
# ### 3. Break (8-8:30/ 30 min)
#
# ### 4. Develop Personal Goals for Module
# - Work on personal backlog
# - Dig deeper into what you don't know or want to know more
#     - ex 1: Take a part a computer, document pieces, etc.
#     - ex 2: Look into assembly language
#     - ex 3: Analyze technical specifications for CPU and write a technical document
#
# ### 5. Deliverables for Week 1 Hardware & OS
# Bart
# 1. Spec out PC and check out architecture, maybe check out pcpic (medium post)
# 1. Break down Python script execution in assembly (Medium post on how it works)
#
# Ross
# 1. Wants to learn more about compilers and executers
# 1. cheatengine
#
#
# ### .6 Assignment/ Homework
# - Read in A+ Chapter 2 before class on Saturday
# - Recommended reading Chapters 4, 5, 6, 7 and skim Chapter 8
