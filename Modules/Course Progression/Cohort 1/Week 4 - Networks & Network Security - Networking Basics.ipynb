# %% [markdown]
# # Week 4 - Networking Basics
#
# ### Weekly Objectives
#
#
# - Idea of the different types of networks and what makes each one different
# - How to use topologies to design networks as a planning and docuemnting tool
# - Basic idea of the different types of connections
# - Understanding of basic network devices, how they work together, and how they are all different
# - Specific difference between a router and a switch
#
#
# ##### MAIN POINTS
# - Types of Networks (1 hour)
#     - LAN
#     - WAN
#     - WLAN
#     - SAN
#     - MAN
#     - CAN
#     - PAN
#     - VPN's (High Level)
#     - VLAN's (High Level)
#         - Show Diagrams of different types of networks and have students guess what they are. Develops some class discussion on what the differences are between network types
#
# - Topologies
#     - Bus
#     - Star
#     - Ring
#     - Mesh
#         - Show example topologies and give examples of why and how these topologies are used
#
# - Connection Options
#     - Coaxial
#     - Copper (Cat5)
#     - Fiber
#     - Wireless
#     - Serial
#     - Console
#         - Also can show pictures of different types of cables
#     - Straight-Through vs. Crossover Cables
#
# - Network Devices
#     - Switch
#     - Router
#     - What are differences and Similarities between Switches and Routers?
#     - Servers
#         - DNS Server
#         - Proxy Server
#         - DHCP Server
#     - End Devices
#     - Firewalls
#     - Wireless Access Points
#     - IDS/IPS
#     - Modem
#     - NIC's
#
# - Optional Topics
#     - Ethernet Basics
#
# - Activities
#     - Network Mapping Tools
#     - Cable Demonstration
#     - Download Packet Tracer and demonstrate how to use tool and building a simple Network
#
#
# ### Day 1 - Monday - 12/4/17 - 4 hours
# - This day was spent catching up on stuff from the previous module "Hardware and Operating Systems"
# - Troubleshooting VM images (NAT vs. Bridged)
#     - Uninstalling Virtual Box and reinstalling as an administrator was the solution to this problem
#
#
# ### Day 2 - Tuesday - 12/5/17 - 4 hours
# Basics of Networking
# - Lecture:
#     - [Intro to Networks]( http://localhost:8888/notebooks/Modules/Networking%20%26%20Network%20Security%20-%20Intro%20to%20Networks.ipynb)
# - Lab: Packet Tracer - Building a simple network (Incorporates topolgies, network type, and devices)
#     - I have notes on this I'm just not sure how to link it?
#
# ### Day 3 - Saturday - 12/9/17 - 9 hours
# - Morning Challenge:
#
# - Lab: Scripting Challenge?
#
# - Lecture:
#
#
#
#
#
#
# ### Resources
# - [Network + Text](https://drive.google.com/drive/folders/0B6DDUoHms80LOUJzdmdJajhIN2s)
# - [Network + Exam Study Guide](https://drive.google.com/drive/folders/0B6DDUoHms80LOUJzdmdJajhIN2s)
# - [Netacad Packet Tracer](https://www.netacad.com/campaign/ptdt-4)
# - [Images used during lecture] ()
#
#
# ### Self Study Objectives
# - Network + Text Book - Chapter 1-5
# - Trello board
# - Weekly Deliverable
#
#
# ### Saturday Morning Challenge
# -
