# %% [markdown]
# # Week 5 - IP
#
# ### Weekly Objectives
#
# - What is an IP address?
# - How to convert between binary and decimal numbers
# - How to Subnet a Network address
# - Know what protocols are used and how they are used
# -
# - Understand what Wireshark is and a very basic understanding of how to use it
#
# ##### MAIN POINTS
# - What is IPv4?
# - How does IPv6 change anything?
# - RFC's and using them as a resource
# - Bit
# - Byte
# - Octet
# - Binary Numbers
#     - How it applies to IP Addresses
# - Network Addresses
# - Broadcast Addresses
#     - Layer 2 broadcast addresses
#     - Broadcast
#     - Unicast
#     - Multicast
#
# - Different IP address Classes
#
# - Subnetting
#
# - Wireshark
#     - Looking at packets
#     - Filters in wireshark
#
# - Ports
# - Protocols
#
#
#
# ### Day 1 - Monday - 12/11/17 - 4 hours
# - Lecture: IP Addresses
# - OSI Model
#
#
# ### Day 2 - Tuesday -  12/12/17 - 4 hours
# - Lecture: Chapter 7
#     - [Networking & Network Secruity Fundamentals - IP Addresses](http://localhost:8888/notebooks/Modules/Networking%20%26%20Network%20Security%20Fundamentals%20-%20IP%20Addresses.ipynb)
# - Lab:
#
# ### Day 3 - Saturday - 12/16/17 - 9 hours
# - Morning Challenge:
#
# - Hands On Lab:
#
# - Lab: Subnet Calculator Program Challenge
#     - See Project module on Subnet Calculator
#     - Resources used?
#
# ### Resources
# - [Network + Text](https://drive.google.com/drive/folders/0B6DDUoHms80LOUJzdmdJajhIN2s)
# - [Network + Exam Study Guide](https://drive.google.com/drive/folders/0B6DDUoHms80LOUJzdmdJajhIN2s)
# - [Netacad Packet Tracer](https://www.netacad.com/campaign/ptdt-4)
# - [RFC](https://www.ietf.org/rfc.html)
#
#
# ### Self Study Objectives
# - Network + Text Book - Chapter 1-5
# - Trello board
# - Weekly Deliverable
#
#
# ### Saturday Morning Challenge
# -
