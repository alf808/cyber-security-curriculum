# %% [markdown]
# ### Day 1 - Monday - 4 hours
# - Week 1 Retrospective
#  - Student Deliverable Presentations (30-60 mins)
#  - Student Deliverable Catchup (60 mins)
#  - BIOS Security Basics (30 mins)
#      - TODO: Students should create a Hardware playbook in their security handbook
#      - Boot Password
#      - Security Settings Password
#      - Difference between BIOS and UEFI
#          - BIOS
#              - MBR shows location of boot sector
#              - Boot sector contains code that points to the file location of the boot manager(bootmgr)
#              - Boot manager knows how to launch the OS
#          - UEFI
#              - Loads the boot manager directly
#      - Windows: Unable to locate bootmgr is a standard Windows error message stating which can be signs of corruption or sometimes a virus
#      - Show `bcdedit /enum` to show Boot Manager and Boot Loader settings in Windows
#
#
#  ~~- Trusted Platform Module (Sec+)(20-30 mins)
#      - What is it?
#      - How does it work?
#      - How to enable it
#      - Windows Bitlocker Integration~~
#
#    - Windows Registry Walkthrough Demo (30 mins)
#      - TODO: Have students start a Windows Registry section in their playbook
#      - What is the registry?
#      - Where do the registry files live on the system and how can you see those files
#          - Enable show hidden files and folders in Folder Options
#          - Browse to C:\Windows\System32\config
#              - Sort by type and see the main "File" types
#                  - DEFAULT
#                  - SAM <- This is the Security Account Manager
#                  - SECURITY
#                  - SOFTWARE
#                  - SYSTEM
#          - User specific registry data is located in C:\Users\username\AppData\Local\Microsoft\Windows\UsrClass.dat
#      - How to access the registry with regedt32
#      - What are the root keys in the registry
#          - Explain the common nomenclature for referencing root keys:
#      - Searching for things in the registry
#
#
# ### Day 2 - Tuesday - 4 hours
# - Install Windows as a VM (https://developer.microsoft.com/en-us/microsoft-edge/tools/vms/)
# - Windows Registry Demo Continuation
#     - Start a Windows Registry playbook!!!
#     - How to and when to backup the registry
#     - How to reinstall a former backup to the registry
#     - How to edit the registry
#     - Standard types of values in the registry:
#       - String
#       - Binary
#       - DWORD - 32-bit binary
#       - QWORD - 64-bit binary
#
#     - Common place for malware: `HKLM\SOFTWARE\Microsoft\Windows\CurrentVersion\Run` (Document in playbook)
#
#     - Go over reg CLI tool(interactive demo)
#       - Talk about using CLI and experimenting
#       - [reg.exe Docs](https://technet.microsoft.com/en-us/library/bb490984.aspx)
#       - reg /?
#           - `reg /? | more`
#       - reg query /?
#       - Usable with multiple machines across a domain
#
#     - Go over regsvr32 tool and it's purpose(no demo)
#       - Used to register DLL's
#       - `regsvr32 some.dll //register DLL`
#       - `regsvr32 /u some.dll //unregister DLL`
#       - 64-bit version lives in the %SystemRoot%Syswow64 folder
#
#     - Show how to write a batch file and brief convo about scripting
#       - Display the output of a registry query
#           - reg query HKLM\Software
#           - reg add "HKCU\SOFTWARE\Microsoft\Windows\CurrentVersion\Run" /V "My App" /t REG_SZ /f /d "C:\MyAppPath\MyApp.exe"
#       - Add PAUSE statement to prevent exit
#       - Add an ipconfig /all
#       - Add a ping to google.com
#       - Add a traceroute to google.com
#       - Add comments to file
#       - Remove PAUSE and append to file >>
#      - Show Powershell Methods:
#          - Get-ChildItem -Path Registry::HKEY_CURRENT_USER
#          - Get-ChildItem -Path Registry::HKCU
#
#   - Show results of running Auslogic Registry Cleaner
#
#   - What are environment variables?
#       - At cmd.exe, show all variables with `SET` command
#       - View individual settings with `echo %windir%` syntax
#
#   - Applications, processes, services
#       - What are the difference between each?
#       - Different versions of Task Manager prior to Windows 8 and after
#           - Fundamental shift in philosophy in showing process info
#           - Have both Windows 7 and Windows 10 images open
#       - Task Manager Demo
#           - tasklist, taskkill /f /pid 1111
#           - Launch with `taskmgr` from search
#           - Shortcut Ctrl-Shift-Esc
#           - Switch To to bring application to front
#           - New task to launch a program (cmd example)
#           - Right click on application and select Go To Process to go to process view
#           - Process Tab:
#               - Name
#               - User that launched the process
#               - PID (Enable with View->Select Columns->Select PID)
#               - Show processes from all users checkbox
#               - Context Menu:
#                   - Open File Location
#                   - End Process
#                   - End Process Tree
#                   - UAC Virtualization
#                   - Create Dump File
#                   - Set Priority
#                   - Set Affinity
#                   - Go To Services(services.msc)
#                       - Can start any service from `net start <service name>`
#                       - Can stop any service from `net stop <service name>`
#           - Performance Tab:
#               - Multiple CPUs/Cores
#   - Activity: Download free Process Explorer tool for greater control over processes, visibility to process trees, etc.../
#               - What is the pagefile?
#           - Networking and Users Tabs:
#               - Can logoff other users from the Users tab
#           - App history in new versions
#           - Startup tab in new versions of Windows 8 and above
#               - Prior was accessible via `msconfig`
#
#       - Performance Monitor
#           - perfmon.msc
#           - Toggle checkbox to see descriptions of Add Counters
#           - What are objects?
#           - What are counters?
#           - What are Data Collector Sets?
#               - How to view reports
#               - What can you collect?
#                   - System counters
#                   - Event trace data
#                   - Registry Values
#               - Generate report from perfmon
#                   - perfmon /report (generate current system diagnostics report of system)
#                   - perfmon /report "Report Name" to run user defined report
#                   - View report in Reports->System->System Diagnostics
#                   - View warnings
#               - Export Data Collector Set with logman
#                   - `logman export -n "TCP_Data" -xml "C:\Users\IEUser\TCP_Data_Template.xml"`
#
#       - Brief discussion of COM ojbects and ODBC
#
#   - Activity: Have students build out their Windows Registry Security playbook for common exploits and how to clean at both user and enterprise level
#
#   - Activity: Research how viruses target the bootmgr and how to protect it
#   - Activity: Start to compile Malware Analysis guide using Task Manager
#       - What are the standard Windows services running on a new system?
#       - How do you account for hidden processes?
#       - What are some common troubleshooting tools you can use to investigate Windows? (https://peter.hahndorf.eu/tech/malware.html)
#   - Activity: Setup critical system monitoring in Performance Monitor
#   - Activity: Create a SysInternals malware monitoring implementation guide
#       - We will create infected machines to test this against
#   - Activity: Create a policy and implement a Data Collector Set to ensure that critical registry values are unchanged
#   - Activity: Create a custom Data Collector Set and export to be copied across to other systems
#
# ### Day 3 - Saturday - 9 hours
#
# - Intro to Batch scripting (30-60 minutes)
#     - What is batch scripting
#     - Variables
#     - Return codes
#     - stdin, stdout, stderr
#     - If/Then
#     - Loops
#     - Functions
#     - Parsing Input
#     - Logging
#
# - Batch Scripting Exercise (All Day)
#     - Comment your script
#     - Test your progress iteratively
#     - Commit early, commit often
#     - Deliverable should be it's own repo with a descriptive README and nicely named file
#
#
# ### Resources
# - [A+ Ninth Edition Study Guide](https://drive.google.com/file/d/1sBO4JPU8b43FzC03mTctugJc-ICHLZlP/view?usp=sharing)
# - [A+ 220-902 Exam Study Objectives](https://drive.google.com/open?id=1iQiPuF129U91mHgp1A2SPvf-0FuR43rT)
# - [Anatomy of BIOS Security](http://resources.infosecinstitute.com/anatomy-of-bios-security/)
#
#
# ### Self Study Objectives
# - Read A+ chapter 13, 15, 17 in detail
# - Read A+ chapter 18, skimming okay
# - Read [Anatomy of BIOS Security](http://resources.infosecinstitute.com/anatomy-of-bios-security/) & Create Hardware Security Module
# - Read [Simple Windows Batch Scripting for Intrusion Discovery](https://www.sans.org/reading-room/whitepapers/auditing/simple-windows-batch-scripting-intrusion-discovery-33193)
