# %% [markdown]
# ## Level 0
# - `ls`
# - Copy password to clipboard
# - `boJ9jbbUNNfktd78OOpsqOltutMc3MY1`
#
# ## Level 1
# - `ls`
# - `cat ./-`
# - `CV1DtqXWVFXTvM2F0k09SHz0YwRINYA9`
#
# ## Level 2
# - `ls`
# - `cat spaces\ in\ this\ filename`
# - `UmHadQclWmgdLOKQ3YNgjWxGoRMb5luK`
#
# ## Level 3
# - `ls`
# - `cat inhere/.hidden`
# - `pIwrPrtPN36QITSp3EQaw936yaFoFgAB`
#
# ## Level 4
# - `ls`
# - `file inhere/*`
# - `koReBOKuIDDepwhWk7jZC0RTdopnAYKh`
#
# ## Level 5
# - `find inhere/ -type f -size 1033c` (works)
# - `find inhere/ -type f -size 1033c -exec ls -l {} \;` (alternate)
# - `DXjZPULLxYr17uwoI01bNLQbtFemEgo7`
#
# ## Level 6
# - `find / -type f -user bandit7 -group bandit6 -size 33c` (works)
# - `find / ! -readable -prune -o -type f -user bandit7 -group bandit6 -size 33c -print`
# - `cat /var/lib/dpkg/info/bandit7.password`
# - `HKBPTKQnIay4Fw76bEy8PVxKEDQRKTzs`
# - https://stackoverflow.com/questions/762348/how-can-i-exclude-all-permission-denied-messages-from-find#762360
#
# ## Level 7
# - `cat data.txt | grep millionth`
# - `cvX2JJa4CFALtqS87jk27qwqGhBM9plV`
#
# ## Level 8
# - `sort data.txt | uniq -c | sort | head -n 1`
# - `UsvVyFSfZZWbi6wgC7dAFyFuR6jQQUhR`
#
# ## Level 9
# - `strings data.txt | grep '=='`
# - `truKLdjsbJ5g7yyJ2X2R0o3a5HQJFuLk`
#
# ## Level 10
# - `base64 -d data.txt`
# - `IFukwKGsFW8MOq3IRFqrxE1hxTNEbUPR`
#
# ## Level 11
# - `cat data.txt | tr 'A-Za-z' 'N-ZA-Mn-za-m'` (ROT13)
# - `5Te8Y4drgCRfCx8ugdwuEX8KFC6k2EUu`
#
# ## Level 12
# - `mkdir /tmp/jason`
# - `cp data.txt /tmp/jason`
# - `xxd -r data.txt > data1`
# - `file data1`
# - `gzip -d -c data1 > data2`
# - `file data2`
# - `bzip2 -d -c data2 > data3`
# - `file data3`
# - `gzip -d -c data3 > data4`
# - `tar xkf data4`
# - `file data5.bin`
# - `tar xkf data5.bin`
# - `file data6.bin`
# - `bzip2 -d -c data6.bin > data7`
# - `file data7`
# - `tar xkf data7`
# - `file data8.bin`
# - `gzip -d -c data8.bin > data9`
# - `file data9`
# - `cat data9`
# - `8ZjyCRiBWFYkneahHwxCv3wb2a1ORpYL`
#
# ## Level 13
# - `ll /etc/bandit_pass/bandit13`
# - `ls ~`
# - `ssh -i sshkey.private bandit14@localhost`
# - `cat /etc/bandit_pass/bandit14`
# - `4wcYUJFw0k0XLShlDzztnTBHiqxU3b3e`
#
# ## Level 14
# - `nc localhost 30000`
# - `Paste at blank prompt: 4wcYUJFw0k0XLShlDzztnTBHiqxU3b3e`
# - `BfMYroe26WYalil77FoDi9qh59eK5xNr`
#
# ## Level 15
# - `openssl s_client -connect localhost:30001 -ign_eof`
# - `Paste at blank prompt: cluFn7wTiGryunymYOu4RcffSxQluehd`
# - `cluFn7wTiGryunymYOu4RcffSxQluehd`
#
# ## Level 16
# - `nmap localhost -p 31000-32000`
# - `openssl s_client -connect localhost:31046`
# - `openssl s_client -connect localhost:31518`
# - `openssl s_client -connect localhost:31691`
# - `openssl s_client -connect localhost:31790`
# ```
# -----BEGIN RSA PRIVATE KEY-----
# MIIEogIBAAKCAQEAvmOkuifmMg6HL2YPIOjon6iWfbp7c3jx34YkYWqUH57SUdyJ
# imZzeyGC0gtZPGujUSxiJSWI/oTqexh+cAMTSMlOJf7+BrJObArnxd9Y7YT2bRPQ
# Ja6Lzb558YW3FZl87ORiO+rW4LCDCNd2lUvLE/GL2GWyuKN0K5iCd5TbtJzEkQTu
# DSt2mcNn4rhAL+JFr56o4T6z8WWAW18BR6yGrMq7Q/kALHYW3OekePQAzL0VUYbW
# JGTi65CxbCnzc/w4+mqQyvmzpWtMAzJTzAzQxNbkR2MBGySxDLrjg0LWN6sK7wNX
# x0YVztz/zbIkPjfkU1jHS+9EbVNj+D1XFOJuaQIDAQABAoIBABagpxpM1aoLWfvD
# KHcj10nqcoBc4oE11aFYQwik7xfW+24pRNuDE6SFthOar69jp5RlLwD1NhPx3iBl
# J9nOM8OJ0VToum43UOS8YxF8WwhXriYGnc1sskbwpXOUDc9uX4+UESzH22P29ovd
# d8WErY0gPxun8pbJLmxkAtWNhpMvfe0050vk9TL5wqbu9AlbssgTcCXkMQnPw9nC
# YNN6DDP2lbcBrvgT9YCNL6C+ZKufD52yOQ9qOkwFTEQpjtF4uNtJom+asvlpmS8A
# vLY9r60wYSvmZhNqBUrj7lyCtXMIu1kkd4w7F77k+DjHoAXyxcUp1DGL51sOmama
# +TOWWgECgYEA8JtPxP0GRJ+IQkX262jM3dEIkza8ky5moIwUqYdsx0NxHgRRhORT
# 8c8hAuRBb2G82so8vUHk/fur85OEfc9TncnCY2crpoqsghifKLxrLgtT+qDpfZnx
# SatLdt8GfQ85yA7hnWWJ2MxF3NaeSDm75Lsm+tBbAiyc9P2jGRNtMSkCgYEAypHd
# HCctNi/FwjulhttFx/rHYKhLidZDFYeiE/v45bN4yFm8x7R/b0iE7KaszX+Exdvt
# SghaTdcG0Knyw1bpJVyusavPzpaJMjdJ6tcFhVAbAjm7enCIvGCSx+X3l5SiWg0A
# R57hJglezIiVjv3aGwHwvlZvtszK6zV6oXFAu0ECgYAbjo46T4hyP5tJi93V5HDi
# Ttiek7xRVxUl+iU7rWkGAXFpMLFteQEsRr7PJ/lemmEY5eTDAFMLy9FL2m9oQWCg
# R8VdwSk8r9FGLS+9aKcV5PI/WEKlwgXinB3OhYimtiG2Cg5JCqIZFHxD6MjEGOiu
# L8ktHMPvodBwNsSBULpG0QKBgBAplTfC1HOnWiMGOU3KPwYWt0O6CdTkmJOmL8Ni
# blh9elyZ9FsGxsgtRBXRsqXuz7wtsQAgLHxbdLq/ZJQ7YfzOKU4ZxEnabvXnvWkU
# YOdjHdSOoKvDQNWu6ucyLRAWFuISeXw9a/9p7ftpxm0TSgyvmfLF2MIAEwyzRqaM
# 77pBAoGAMmjmIJdjp+Ez8duyn3ieo36yrttF5NSsJLAbxFpdlc1gvtGCWW+9Cq0b
# dxviW8+TFVEBl1O4f7HVm6EpTscdDxU+bCXWkfjuRb7Dy9GOtt9JPsX8MBTakzh3
# vBgsyi/sN3RqRBcGU40fOoZyfAMT8s1m/uYv52O6IgeuZ/ujbjY=
# -----END RSA PRIVATE KEY-----
# ```
#
# ## Level 17
# From previous level:
# - `Paste contents of file in a file named: level17_rsa`
# - `Connect with the command: ssh -p 2220 bandit.labs.overthewire.org -l bandit17 -i level17_rsa`
# New challenge:
# - `diff passwords.old passwords.new`
# - `kfBf3eYk5BPBRzwjqutbbfE887SVc5Yd`
#
# ## Level 18
# - `ssh -p 2220 bandit.labs.overthewire.org -l bandit18 'cat readme'`
# - `IueksS7Ubh8G3DCwVzrTd8rAVOwq3M5x`
#
# ## Level 19
# - `ll`
# - `./bandit20-do`
# - `./bandit20-do id`
# - `./bandit2-do cat /etc/bandit_pass/bandit20`
# - `GbKksEFF4yrVs6il55v6gwY5aVje5f0j`
#
# ## Level 20
# - `ll`
# - `nmap localhost`
# - `tmux` <- to start new tmux session
# - `echo 'GbKksEFF4yrVs6il55v6gwY5aVje5f0j' | nc -l 1234`
# - `Ctrl+b d` <- detach from tmux session but leave it running
# - `./suconnect 1234`
# - `Paste the password: GbKksEFF4yrVs6il55v6gwY5aVje5f0j`
# - `tmux a` <- reatach to tmux session
# - `gE269g2h3mw3pwgrj0Ha9Uoqen1c9DGr`
#
# ## Level 21
# - `ll /etc/cron.d`
# - `cat /etc/cron.d/*`
# - `cat /etc/cronjob_bandit22`
# - `cat /usr/bin/cronjob_bandit22.sh`
# - `cat /tmp/t7O6lds9S0RqQh9aMcz6ShpAoZKF7fgv`
# - `Yk7owGAcWjwMVRwrTesJEwB7WVOiILLI`
#
# ## Level 22
# - `ll /etc/cron.d`
# - `cat /etc/cron.d/cronjob_bandit23`
# - `ll /usr/bin/cronjob_bandit23.sh`
# - `cat /usr/bin/cronjob_bandit23.sh`
# - `echo I am user bandit23 | md5sum | cut -d ' ' -f 1`
# - `cat /tmp/8ca319486bfbbc3663ea0fbe81326349`
# - `jc1udXuA1tiHqjIsL8yaapX5XIAI6i0n`
#
# ## Level 23
# - `ls /etc/cron.d/`
# - `cat /etc/cron.d/cronjob_bandit24`
# - `cat /usr/bin/cronjob_bandit24.sh`
# - `ll /var/spool`
# - `vim /var/spool/bandit24/getit`
# ```
# #!/bin/bash
# cat /etc/bandit_pass/bandit24 > /var/spool/bandit24/bandit24.hackd
# chown bandit23:bandit23 /var/spool/bandit24/bandit24.hackd
# ```
# - `chmod +x /var/spool/bandit24/getit`
# - `ll /var/spool/bandit24/getit` <- should have x flags set
# - `cat /var/spool/bandit24/bandit24.hackd`
# - `UoMYTrfrBFHyQXmg6gzctqAwOmw1IohZ`
#
# ## Level 24
# - `nc localhost 30002`
# - `TODO: Need to write python script to automate input`
