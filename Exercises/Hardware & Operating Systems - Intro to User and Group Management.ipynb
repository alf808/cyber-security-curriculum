# %% [markdown]
# # Intro to User and Group Management
#
# Aloha Systems Nerds,
#
# We are provisioning some long awaited brand new Windoze servers!! We need your help in setting up access for our users and groups within the organization.
#
# Please ensure that these servers are securely setup and we've also never had an official security policy documented and that jerk Ted won't answer his phone anymore. So if you could officially document our new security policy that would be greeeeaaaat :D
#
# #### Windows
# 1. Start with a fresh installation of Windows Server 2016
#     1. Setup a main `devleague` adminstrator account.
#         - This password should not expire
#         - Make secure password and document securely
#
#     1. Ensure that the Guest Account is disabled.
#
#     1. Create Security Policy and document appropriately (Your personal playbook is a good place), we would like a visual chart to demonstrat this to.
#
#     1. We have the following users within our organization that we need to add to the system that play the following roles:
#         1. Bart
#             - Developer/Contractor
#         1. Ross
#             - Accounting Manager
#         1. Nick
#             - Sales Manager
#         1. Mary
#             - Developer/Contractor
#         1. Kaleo
#             - Manager, Developer, System Admin
#         1. Jason
#             - Marketing, Sales, Owner
#         1. Alyssa
#             - Manager, Developer, System Admin
#         1. Tyler
#             - Accountant, Contractor
#         1. Russel
#             - Owner
#         1. Tina
#             - Marketing
#
#     1. We have the following needs within the organization for sharing resources and access policies which we will need you to implement. Please implement this in the most optimal and flexible way since we may have users switch departments or roles but still maintain some of the same responsibilities.
#
#         1. Document location only viewable by managers
#             - There should be a shared location for all managers across all departments, but each department should have a space viewable by their own department managers but not those from other departments.
#
#         1. Each department should have a location where documents are accessible by all people within a single department, including managers, full time employees and contractors.
#
#         1. Each department should further have a place where full time employees can access but contractors within that department cannot.
#
#         1. Owners should have a location for documents that are only accessible by them, but should also be able to access all documents within the organization.
#
#         1. Each department should have a location for all employees and contractors to view documents, but only managers can modify the contents of this directory.
#
#         1. Certain members in the accounting department should be able to see revenue projections created by the Sales team.
#
#     1. Owners should have write access only to all accounting documents.
#
#     1. Create a location where all users from all departments can share public internal documents with anyone authorized to be on the system. Guest account access should not be able to access this directory.
#
#     1. The Developers group should be able to back up this system.
#
#     1. The Developers should be able to monitor the performance of the system and run any needed reports on the health of the system.
#
#     1. The System Admins group will also be responsible for creating new users and groups.
#
#     1. The owners should definitely not be able to add new users and groups (they like to get their hands in everything).
#
#     1. The marketing and sales department will both need to be part of a group that has access to the new laser printer we have coming.
#
# #### Linux
# 1. Tina from Marketing also got us to purchase an Ubuntu 16.04 machine and said it's amaaaazing. Please set up the same settings on the new Ubuntu server as well.
#
# EXTRA BONUS: It would be great if the Developers could automate this task so that anytime someone is onboarded into the company we can easily add them to the system.
